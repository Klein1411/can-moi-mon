# %% [markdown]
# # 03 — Đánh giá trên ảnh sạch và corruption
#
# **Mục tiêu:** Đánh giá E0/E1 trên tám test split và chọn model cuối theo protocol.
#
# > Notebook này chỉ được người dùng chạy thủ công. Codex không được tự động thực thi notebook.

# %% [markdown]
# ## 1. CẤU HÌNH
#
# - Seed mặc định: 42.
# - Dùng đường dẫn tương đối.
# - Mọi comment code phải viết bằng tiếng Việt có dấu.
# - Không ghi kết quả giả vào notebook.

# %%
# TODO: Codex triển khai cell cấu hình theo đặc tả trong NOTEBOOKS.md.

# %% [markdown]
# ## 2. TRIỂN KHAI
#
# Codex bổ sung các cell nhỏ, có kiểm tra lỗi và lưu artifact rõ ràng. Không gộp toàn bộ pipeline vào một cell dài.

# %%
# TODO: Codex triển khai milestone hiện tại. Không tự chạy cell này.

# %% [markdown]
# ## 3. ARTIFACT DỰ KIẾN
#
# - `results/evaluation/split_metrics.csv`
# - `results/evaluation/per_class_metrics.csv`
# - `results/evaluation/predictions.csv`
# - `results/evaluation/summary.json`

# %% [markdown]
# ## 4. TÓM TẮT TRẠNG THÁI
#
# Sau khi người dùng chạy xong, cell cuối phải in trạng thái, đường dẫn artifact và các metric chính. Không điền số liệu trước khi chạy.
